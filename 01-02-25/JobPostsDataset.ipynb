# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('datajob.csv')
data
# Out:
#                                                  jobpost          date  \
# 0      AMERIA Investment Consulting Company\r\nJOB TI...   Jan 5, 2004
# 1      International Research & Exchanges Board (IREX...   Jan 7, 2004
# 2      Caucasus Environmental NGO Network (CENN)\r\nJ...   Jan 7, 2004
# 3      Manoff Group\r\nJOB TITLE:  BCC Specialist\r\n...   Jan 7, 2004
# 4      Yerevan Brandy Company\r\nJOB TITLE:  Software...  Jan 10, 2004
# ...                                                  ...           ...
# 18996  Technolinguistics NGO\r\n\r\n\r\nTITLE:  Senio...  Dec 28, 2015
# 18997  "Coca-Cola Hellenic Bottling Company Armenia" ...  Dec 30, 2015
# 18998  "Coca-Cola Hellenic Bottling Company Armenia" ...  Dec 30, 2015
# 18999  San Lazzaro   LLC\r\n\r\n\r\nTITLE:  Head of O...  Dec 30, 2015
# 19000  "Kamurj" UCO CJSC\r\n\r\n\r\nTITLE:  Lawyer in...  Dec 30, 2015
#
#                                                    Title  \
# ...

# %%
print(data.isnull().sum())
# Out:
# jobpost                 0
# date                    0
# Title                  28
# Company                 7
# AnnouncementCode    17793
# Term                11325
# Eligibility         14071
# Audience            18361
# StartDate            9326
# Duration             8203
# Location               32
# JobDescription       3892
# JobRequirment        2522
# RequiredQual          484
# Salary               9379
# ApplicationP           60
# OpeningDate           706
# Deadline               65
# Notes               16790
# AboutC               6531
# Attach              17442
# Year                    0
# Month                   0
# IT                      0
# dtype: int64

# %%
print(data.columns)
# Out:
# Index(['jobpost', 'date', 'Title', 'Company', 'AnnouncementCode', 'Term',
#        'Eligibility', 'Audience', 'StartDate', 'Duration', 'Location',
#        'JobDescription', 'JobRequirment', 'RequiredQual', 'Salary',
#        'ApplicationP', 'OpeningDate', 'Deadline', 'Notes', 'AboutC', 'Attach',
#        'Year', 'Month', 'IT'],
#       dtype='object')

# %%
data.columns = data.columns.str.strip()  
print(data.columns)
# Out:
# Index(['jobpost', 'date', 'Title', 'Company', 'AnnouncementCode', 'Term',
#        'Eligibility', 'Audience', 'StartDate', 'Duration', 'Location',
#        'JobDescription', 'JobRequirment', 'RequiredQual', 'Salary',
#        'ApplicationP', 'OpeningDate', 'Deadline', 'Notes', 'AboutC', 'Attach',
#        'Year', 'Month', 'IT'],
#       dtype='object')

# %%
print(data.columns)
# Out:
# Index(['jobpost', 'date', 'Title', 'Company', 'AnnouncementCode', 'Term',
#        'Eligibility', 'Audience', 'StartDate', 'Duration', 'Location',
#        'JobDescription', 'JobRequirment', 'RequiredQual', 'Salary',
#        'ApplicationP', 'OpeningDate', 'Deadline', 'Notes', 'AboutC', 'Attach',
#        'Year', 'Month', 'IT'],
#       dtype='object')

# %%
data['Salary'] = pd.to_numeric(data['Salary'], errors='coerce')
data['Salary'].fillna(data['Salary'].mean(), inplace=True)

# %%
print(data['Salary'].head())
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: Salary, dtype: float64

# %%
print(data['Salary'].unique())
# Out:
# [nan]

# %%
data['Salary'].fillna('Not Provided', inplace=True)
data
# Out:
#                                                  jobpost          date  \
# 0      AMERIA Investment Consulting Company\r\nJOB TI...   Jan 5, 2004
# 1      International Research & Exchanges Board (IREX...   Jan 7, 2004
# 2      Caucasus Environmental NGO Network (CENN)\r\nJ...   Jan 7, 2004
# 3      Manoff Group\r\nJOB TITLE:  BCC Specialist\r\n...   Jan 7, 2004
# 4      Yerevan Brandy Company\r\nJOB TITLE:  Software...  Jan 10, 2004
# ...                                                  ...           ...
# 18996  Technolinguistics NGO\r\n\r\n\r\nTITLE:  Senio...  Dec 28, 2015
# 18997  "Coca-Cola Hellenic Bottling Company Armenia" ...  Dec 30, 2015
# 18998  "Coca-Cola Hellenic Bottling Company Armenia" ...  Dec 30, 2015
# 18999  San Lazzaro   LLC\r\n\r\n\r\nTITLE:  Head of O...  Dec 30, 2015
# 19000  "Kamurj" UCO CJSC\r\n\r\n\r\nTITLE:  Lawyer in...  Dec 30, 2015
#
#                                                    Title  \
# ...

# %%
data['Salary'].fillna('Not Provided', inplace=True)
data['Deadline'].fillna('Not Provided', inplace=True)
data['ApplicationP'].fillna('Not Provided', inplace=True)
data
# Out:
#                                                  jobpost          date  \
# 0      AMERIA Investment Consulting Company\r\nJOB TI...   Jan 5, 2004
# 1      International Research & Exchanges Board (IREX...   Jan 7, 2004
# 2      Caucasus Environmental NGO Network (CENN)\r\nJ...   Jan 7, 2004
# 3      Manoff Group\r\nJOB TITLE:  BCC Specialist\r\n...   Jan 7, 2004
# 4      Yerevan Brandy Company\r\nJOB TITLE:  Software...  Jan 10, 2004
# ...                                                  ...           ...
# 18996  Technolinguistics NGO\r\n\r\n\r\nTITLE:  Senio...  Dec 28, 2015
# 18997  "Coca-Cola Hellenic Bottling Company Armenia" ...  Dec 30, 2015
# 18998  "Coca-Cola Hellenic Bottling Company Armenia" ...  Dec 30, 2015
# 18999  San Lazzaro   LLC\r\n\r\n\r\nTITLE:  Head of O...  Dec 30, 2015
# 19000  "Kamurj" UCO CJSC\r\n\r\n\r\nTITLE:  Lawyer in...  Dec 30, 2015
#
#                                                    Title  \
# ...

# %%
data['StartDate'] = pd.to_datetime(data['StartDate'], errors='coerce') 
data['StartDate'].dtype
# Out:
# C:\Users\cvr\AppData\Local\Temp\ipykernel_13320\2046569755.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['StartDate'] = pd.to_datetime(data['StartDate'], errors='coerce')
# dtype('O')

# %%
data['OpeningDate'] = pd.to_datetime(data['OpeningDate'], errors='coerce')

# %%
data['Deadline'] = pd.to_datetime(data['Deadline'], errors='coerce')

# %%
data.drop(columns=['Notes', 'Attach'], inplace=True,errors='ignore')
data.columns
# Out:
# Index(['jobpost', 'date', 'Title', 'Company', 'AnnouncementCode', 'Term',
#        'Eligibility', 'Audience', 'StartDate', 'Duration', 'Location',
#        'JobDescription', 'JobRequirment', 'RequiredQual', 'Salary',
#        'ApplicationP', 'OpeningDate', 'Deadline', 'AboutC', 'Year', 'Month',
#        'IT'],
#       dtype='object')

# %%
data
# Out:
#                                                  jobpost          date  \
# 0      AMERIA Investment Consulting Company\r\nJOB TI...   Jan 5, 2004
# 1      International Research & Exchanges Board (IREX...   Jan 7, 2004
# 2      Caucasus Environmental NGO Network (CENN)\r\nJ...   Jan 7, 2004
# 3      Manoff Group\r\nJOB TITLE:  BCC Specialist\r\n...   Jan 7, 2004
# 4      Yerevan Brandy Company\r\nJOB TITLE:  Software...  Jan 10, 2004
# ...                                                  ...           ...
# 18996  Technolinguistics NGO\r\n\r\n\r\nTITLE:  Senio...  Dec 28, 2015
# 18997  "Coca-Cola Hellenic Bottling Company Armenia" ...  Dec 30, 2015
# 18998  "Coca-Cola Hellenic Bottling Company Armenia" ...  Dec 30, 2015
# 18999  San Lazzaro   LLC\r\n\r\n\r\nTITLE:  Head of O...  Dec 30, 2015
# 19000  "Kamurj" UCO CJSC\r\n\r\n\r\nTITLE:  Lawyer in...  Dec 30, 2015
#
#                                                    Title  \
# ...

# %%
data.drop_duplicates(subset=['Title', 'Company'], keep='first', inplace=True)

# %%
data['jobpost'] = data['jobpost'].str.replace('\r\n', ' ', regex=False)
data['jobpost'] = data['jobpost'].str.strip()

# %%
data
# Out:
#                                                  jobpost          date  \
# 0      AMERIA Investment Consulting Company JOB TITLE...   Jan 5, 2004
# 1      International Research & Exchanges Board (IREX...   Jan 7, 2004
# 2      Caucasus Environmental NGO Network (CENN) JOB ...   Jan 7, 2004
# 3      Manoff Group JOB TITLE:  BCC Specialist POSITI...   Jan 7, 2004
# 4      Yerevan Brandy Company JOB TITLE:  Software De...  Jan 10, 2004
# ...                                                  ...           ...
# 18995  "Transport PIU" State Institution of the RA Mi...  Dec 24, 2015
# 18996  Technolinguistics NGO   TITLE:  Senior Creativ...  Dec 28, 2015
# 18997  "Coca-Cola Hellenic Bottling Company Armenia" ...  Dec 30, 2015
# 18998  "Coca-Cola Hellenic Bottling Company Armenia" ...  Dec 30, 2015
# 18999  San Lazzaro   LLC   TITLE:  Head of Online Sal...  Dec 30, 2015
#
#                                                    Title  \
# ...

# %%
data['Title'] = data['Title'].str.strip()
data['Company'] = data['Company'].str.strip()

# %%
data
# Out:
#                                                  jobpost          date  \
# 0      AMERIA Investment Consulting Company JOB TITLE...   Jan 5, 2004
# 1      International Research & Exchanges Board (IREX...   Jan 7, 2004
# 2      Caucasus Environmental NGO Network (CENN) JOB ...   Jan 7, 2004
# 3      Manoff Group JOB TITLE:  BCC Specialist POSITI...   Jan 7, 2004
# 4      Yerevan Brandy Company JOB TITLE:  Software De...  Jan 10, 2004
# ...                                                  ...           ...
# 18995  "Transport PIU" State Institution of the RA Mi...  Dec 24, 2015
# 18996  Technolinguistics NGO   TITLE:  Senior Creativ...  Dec 28, 2015
# 18997  "Coca-Cola Hellenic Bottling Company Armenia" ...  Dec 30, 2015
# 18998  "Coca-Cola Hellenic Bottling Company Armenia" ...  Dec 30, 2015
# 18999  San Lazzaro   LLC   TITLE:  Head of Online Sal...  Dec 30, 2015
#
#                                                    Title  \
# ...

# %%
data.columns = data.columns.str.strip()

# %%
print(data.head())
# Out:
#                                              jobpost          date  \
# 0  AMERIA Investment Consulting Company JOB TITLE...   Jan 5, 2004
# 1  International Research & Exchanges Board (IREX...   Jan 7, 2004
# 2  Caucasus Environmental NGO Network (CENN) JOB ...   Jan 7, 2004
# 3  Manoff Group JOB TITLE:  BCC Specialist POSITI...   Jan 7, 2004
# 4  Yerevan Brandy Company JOB TITLE:  Software De...  Jan 10, 2004
#
#                                                Title  \
# 0                            Chief Financial Officer
# 1  Full-time Community Connections Intern (paid i...
# 2                                Country Coordinator
# 3                                     BCC Specialist
# 4                                 Software Developer
#
#                                            Company AnnouncementCode Term  \
# 0             AMERIA Investment Consulting Company              NaN  NaN
# 1  International Research & Exchanges Board (IREX)              NaN  NaN
# ...

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14918 entries, 0 to 18999
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   jobpost           14918 non-null  object
#  1   date              14918 non-null  object
#  2   Title             14905 non-null  object
#  3   Company           14917 non-null  object
#  4   AnnouncementCode  987 non-null    object
#  5   Term              5833 non-null   object
#  6   Eligibility       3841 non-null   object
#  7   Audience          466 non-null    object
#  8   StartDate         2131 non-null   object
#  9   Duration          8463 non-null   object
#  10  Location          14892 non-null  object
#  11  JobDescription    11867 non-null  object
#  12  JobRequirment     12994 non-null  object
#  13  RequiredQual      14623 non-null  object
#  14  Salary            14918 non-null  object
#  15  ApplicationP      14918 non-null  object
# ...

# %%
data
# Out:
#                                                  jobpost          date  \
# 0      AMERIA Investment Consulting Company JOB TITLE...   Jan 5, 2004
# 1      International Research & Exchanges Board (IREX...   Jan 7, 2004
# 2      Caucasus Environmental NGO Network (CENN) JOB ...   Jan 7, 2004
# 3      Manoff Group JOB TITLE:  BCC Specialist POSITI...   Jan 7, 2004
# 4      Yerevan Brandy Company JOB TITLE:  Software De...  Jan 10, 2004
# ...                                                  ...           ...
# 18995  "Transport PIU" State Institution of the RA Mi...  Dec 24, 2015
# 18996  Technolinguistics NGO   TITLE:  Senior Creativ...  Dec 28, 2015
# 18997  "Coca-Cola Hellenic Bottling Company Armenia" ...  Dec 30, 2015
# 18998  "Coca-Cola Hellenic Bottling Company Armenia" ...  Dec 30, 2015
# 18999  San Lazzaro   LLC   TITLE:  Head of Online Sal...  Dec 30, 2015
#
#                                                    Title  \
# ...

# %%
print(data.isnull().sum())
# Out:
# jobpost                 0
# date                    0
# Title                  13
# Company                 1
# AnnouncementCode    13931
# Term                 9085
# Eligibility         11077
# Audience            14452
# StartDate           12787
# Duration             6455
# Location               26
# JobDescription       3051
# JobRequirment        1924
# RequiredQual          295
# Salary                  0
# ApplicationP            0
# OpeningDate           681
# Deadline             1683
# AboutC               5261
# Year                    0
# Month                   0
# IT                      0
# dtype: int64

# %%
data.fillna({'Deadline': 'Not known'}, inplace=True)

# %%
data['Deadline']
# Out:
# 0        2004-01-26 00:00:00
# 1        2004-01-12 00:00:00
# 2                  Not known
# 3                  Not known
# 4                  Not known
#                 ...
# 18995              Not known
# 18996    2016-01-28 00:00:00
# 18997    2016-01-20 00:00:00
# 18998    2016-01-20 00:00:00
# 18999    2016-01-29 00:00:00
# Name: Deadline, Length: 14918, dtype: object

# %%
print(data.isnull().sum())
# Out:
# jobpost                 0
# date                    0
# Title                  13
# Company                 1
# AnnouncementCode    13931
# Term                 9085
# Eligibility         11077
# Audience            14452
# StartDate           12787
# Duration             6455
# Location               26
# JobDescription       3051
# JobRequirment        1924
# RequiredQual          295
# Salary                  0
# ApplicationP            0
# OpeningDate           681
# Deadline                0
# AboutC               5261
# Year                    0
# Month                   0
# IT                      0
# dtype: int64

# %%
data.fillna({'Eligibility': 'All interested and qualified candidates.'}, inplace=True)

# %%
print(data.isnull().sum())
# Out:
# jobpost                 0
# date                    0
# Title                  13
# Company                 1
# AnnouncementCode    13931
# Term                 9085
# Eligibility             0
# Audience            14452
# StartDate           12787
# Duration             6455
# Location               26
# JobDescription       3051
# JobRequirment        1924
# RequiredQual          295
# Salary                  0
# ApplicationP            0
# OpeningDate           681
# Deadline                0
# AboutC               5261
# Year                    0
# Month                   0
# IT                      0
# dtype: int64

# %%
data['Audience'].fillna(data['Audience'].mode()[0], inplace=True)

# %%
print(data.isnull().sum())
# Out:
# jobpost                 0
# date                    0
# Title                  13
# Company                 1
# AnnouncementCode    13931
# Term                 9085
# Eligibility             0
# Audience                0
# StartDate           12787
# Duration             6455
# Location               26
# JobDescription       3051
# JobRequirment        1924
# RequiredQual          295
# Salary                  0
# ApplicationP            0
# OpeningDate           681
# Deadline                0
# AboutC               5261
# Year                    0
# Month                   0
# IT                      0
# dtype: int64

# %%
data.columns
# Out:
# Index(['jobpost', 'date', 'Title', 'Company', 'AnnouncementCode', 'Term',
#        'Eligibility', 'Audience', 'StartDate', 'Duration', 'Location',
#        'JobDescription', 'JobRequirment', 'RequiredQual', 'Salary',
#        'ApplicationP', 'OpeningDate', 'Deadline', 'AboutC', 'Year', 'Month',
#        'IT'],
#       dtype='object')

# %%
data
# Out:
#                                                  jobpost          date  \
# 0      AMERIA Investment Consulting Company JOB TITLE...   Jan 5, 2004
# 1      International Research & Exchanges Board (IREX...   Jan 7, 2004
# 2      Caucasus Environmental NGO Network (CENN) JOB ...   Jan 7, 2004
# 3      Manoff Group JOB TITLE:  BCC Specialist POSITI...   Jan 7, 2004
# 4      Yerevan Brandy Company JOB TITLE:  Software De...  Jan 10, 2004
# ...                                                  ...           ...
# 18995  "Transport PIU" State Institution of the RA Mi...  Dec 24, 2015
# 18996  Technolinguistics NGO   TITLE:  Senior Creativ...  Dec 28, 2015
# 18997  "Coca-Cola Hellenic Bottling Company Armenia" ...  Dec 30, 2015
# 18998  "Coca-Cola Hellenic Bottling Company Armenia" ...  Dec 30, 2015
# 18999  San Lazzaro   LLC   TITLE:  Head of Online Sal...  Dec 30, 2015
#
#                                                    Title  \
# ...

# %%
data.drop(columns=['AnnouncementCode'], inplace=True)

# %%
data
# Out:
#                                                  jobpost          date  \
# 0      AMERIA Investment Consulting Company JOB TITLE...   Jan 5, 2004
# 1      International Research & Exchanges Board (IREX...   Jan 7, 2004
# 2      Caucasus Environmental NGO Network (CENN) JOB ...   Jan 7, 2004
# 3      Manoff Group JOB TITLE:  BCC Specialist POSITI...   Jan 7, 2004
# 4      Yerevan Brandy Company JOB TITLE:  Software De...  Jan 10, 2004
# ...                                                  ...           ...
# 18995  "Transport PIU" State Institution of the RA Mi...  Dec 24, 2015
# 18996  Technolinguistics NGO   TITLE:  Senior Creativ...  Dec 28, 2015
# 18997  "Coca-Cola Hellenic Bottling Company Armenia" ...  Dec 30, 2015
# 18998  "Coca-Cola Hellenic Bottling Company Armenia" ...  Dec 30, 2015
# 18999  San Lazzaro   LLC   TITLE:  Head of Online Sal...  Dec 30, 2015
#
#                                                    Title  \
# ...

# %%
data['Audience'].fillna(data['Audience'].mode()[0], inplace=True)

# %%
print(data.isnull().sum())
# Out:
# jobpost               0
# date                  0
# Title                13
# Company               1
# Term               9085
# Eligibility           0
# Audience              0
# StartDate         12787
# Duration           6455
# Location             26
# JobDescription     3051
# JobRequirment      1924
# RequiredQual        295
# Salary                0
# ApplicationP          0
# OpeningDate         681
# Deadline              0
# AboutC             5261
# Year                  0
# Month                 0
# IT                    0
# dtype: int64

# %%
data.fillna({'StartDate':'ASAP'},inplace=True)

# %%
data.fillna({'StartDate':'Unknown'},inplace=True)

# %%
print(data.isnull().sum())
# Out:
# jobpost              0
# date                 0
# Title               13
# Company              1
# Term              9085
# Eligibility          0
# Audience             0
# StartDate            0
# Duration          6455
# Location            26
# JobDescription    3051
# JobRequirment     1924
# RequiredQual       295
# Salary               0
# ApplicationP         0
# OpeningDate        681
# Deadline             0
# AboutC            5261
# Year                 0
# Month                0
# IT                   0
# dtype: int64

# %%
data.fillna({'Term':'FullTime'},inplace=True)

# %%
print(data.isnull().sum())
# Out:
# jobpost              0
# date                 0
# Title               13
# Company              1
# Term                 0
# Eligibility          0
# Audience             0
# StartDate            0
# Duration          6455
# Location            26
# JobDescription    3051
# JobRequirment     1924
# RequiredQual       295
# Salary               0
# ApplicationP         0
# OpeningDate        681
# Deadline             0
# AboutC            5261
# Year                 0
# Month                0
# IT                   0
# dtype: int64

# %%
data.fillna({'Eligibility':'All interested and qualified candidates.'},inplace=True)

# %%
print(data.isnull().sum())
# Out:
# jobpost              0
# date                 0
# Title               13
# Company              1
# Term                 0
# Eligibility          0
# Audience             0
# StartDate            0
# Duration          6455
# Location            26
# JobDescription    3051
# JobRequirment     1924
# RequiredQual       295
# Salary               0
# ApplicationP         0
# OpeningDate        681
# Deadline             0
# AboutC            5261
# Year                 0
# Month                0
# IT                   0
# dtype: int64

# %%
data.fillna({'AboutC':'Unknown'},inplace=True)

# %%
print(data.isnull().sum())
# Out:
# jobpost              0
# date                 0
# Title               13
# Company              1
# Term                 0
# Eligibility          0
# Audience             0
# StartDate            0
# Duration          6455
# Location            26
# JobDescription    3051
# JobRequirment     1924
# RequiredQual       295
# Salary               0
# ApplicationP         0
# OpeningDate        681
# Deadline             0
# AboutC               0
# Year                 0
# Month                0
# IT                   0
# dtype: int64

# %%
print(data['JobDescription'])
# Out:
# 0        AMERIA Investment Consulting Company is seekin...
# 1                                                      NaN
# 2        Public outreach and strengthening of a growing...
# 3        The LEAD (Local Enhancement and Development fo...
# 4                                                      NaN
#                                ...
# 18995    The incumbent will be responsible for supporti...
# 18996    A tech startup of Technolinguistics based in N...
# 18997                                                  NaN
# 18998                                                  NaN
# 18999    San Lazzaro LLC is looking for a well-experien...
# Name: JobDescription, Length: 14918, dtype: object

# %%
data.fillna({'JobDescription':'Unknown'},inplace=True)

# %%
print(data.isnull().sum())
# Out:
# jobpost              0
# date                 0
# Title               13
# Company              1
# Term                 0
# Eligibility          0
# Audience             0
# StartDate            0
# Duration          6455
# Location            26
# JobDescription       0
# JobRequirment     1924
# RequiredQual       295
# Salary               0
# ApplicationP         0
# OpeningDate        681
# Deadline             0
# AboutC               0
# Year                 0
# Month                0
# IT                   0
# dtype: int64

# %%
data.fillna({'JobRequirment':'Unknown'},inplace=True)

# %%
print(data.isnull().sum())
# Out:
# jobpost              0
# date                 0
# Title               13
# Company              1
# Term                 0
# Eligibility          0
# Audience             0
# StartDate            0
# Duration          6455
# Location            26
# JobDescription       0
# JobRequirment        0
# RequiredQual       295
# Salary               0
# ApplicationP         0
# OpeningDate        681
# Deadline             0
# AboutC               0
# Year                 0
# Month                0
# IT                   0
# dtype: int64

# %%
data.columns
# Out:
# Index(['jobpost', 'date', 'Title', 'Company', 'Term', 'Eligibility',
#        'Audience', 'StartDate', 'Duration', 'Location', 'JobDescription',
#        'JobRequirment', 'RequiredQual', 'Salary', 'ApplicationP',
#        'OpeningDate', 'Deadline', 'AboutC', 'Year', 'Month', 'IT'],
#       dtype='object')

# %%
data
# Out:
#                                                  jobpost          date  \
# 0      AMERIA Investment Consulting Company JOB TITLE...   Jan 5, 2004
# 1      International Research & Exchanges Board (IREX...   Jan 7, 2004
# 2      Caucasus Environmental NGO Network (CENN) JOB ...   Jan 7, 2004
# 3      Manoff Group JOB TITLE:  BCC Specialist POSITI...   Jan 7, 2004
# 4      Yerevan Brandy Company JOB TITLE:  Software De...  Jan 10, 2004
# ...                                                  ...           ...
# 18995  "Transport PIU" State Institution of the RA Mi...  Dec 24, 2015
# 18996  Technolinguistics NGO   TITLE:  Senior Creativ...  Dec 28, 2015
# 18997  "Coca-Cola Hellenic Bottling Company Armenia" ...  Dec 30, 2015
# 18998  "Coca-Cola Hellenic Bottling Company Armenia" ...  Dec 30, 2015
# 18999  San Lazzaro   LLC   TITLE:  Head of Online Sal...  Dec 30, 2015
#
#                                                    Title  \
# ...

# %%
if 'Notes' in data.columns:
    data.drop(columns=['Notes'], inplace=True)
else:
    print("Column 'Notes' does not exist.")
# Out:
# Column 'Notes' does not exist.

# %%
data['Title'].fillna(data['Title'].mode()[0], inplace=True)

# %%
print(data.isnull().sum())
# Out:
# jobpost              0
# date                 0
# Title                0
# Company              1
# Term                 0
# Eligibility          0
# Audience             0
# StartDate            0
# Duration          6455
# Location            26
# JobDescription       0
# JobRequirment        0
# RequiredQual       295
# Salary               0
# ApplicationP         0
# OpeningDate        681
# Deadline             0
# AboutC               0
# Year                 0
# Month                0
# IT                   0
# dtype: int64

# %%
data['RequiredQual'].fillna(data['Title'].mode()[0], inplace=True)
print(data['RequiredQual'])
# Out:
# 0        To perform this job successfully, an\r\nindivi...
# 1        - Bachelor's Degree; Master's is preferred;\r\...
# 2        - Degree in environmentally related field, or ...
# 3        - Advanced degree in public health, social sci...
# 4        - University degree; economical background is ...
#                                ...
# 18995    - University degree in Civil Engineering, Econ...
# 18996    - At least 5 years of experience in Interface/...
# 18997    - University degree, ideally business related;...
# 18998    - Degree in Business, Marketing or a related f...
# 18999    - At least 1 year of experience in online sale...
# Name: RequiredQual, Length: 14918, dtype: object

# %%
print(data['RequiredQual'].isnull().sum())
# Out:
# 0

# %%
if 'Attach' in data.columns:
    data.drop(columns=['Attach'], inplace=True)
else:
    print("Column 'Attach' does not exist.")
# Out:
# Column 'Attach' does not exist.

# %%
data['Company'].fillna(data['Company'].mode()[0], inplace=True)
print(data['Company'])
# Out:
# 0                     AMERIA Investment Consulting Company
# 1          International Research & Exchanges Board (IREX)
# 2                Caucasus Environmental NGO Network (CENN)
# 3                                             Manoff Group
# 4                                   Yerevan Brandy Company
#                                ...
# 18995    "Transport PIU" State Institution of the RA Mi...
# 18996                                Technolinguistics NGO
# 18997    "Coca-Cola Hellenic Bottling Company Armenia" ...
# 18998    "Coca-Cola Hellenic Bottling Company Armenia" ...
# 18999                                    San Lazzaro   LLC
# Name: Company, Length: 14918, dtype: object

# %%
print(data['Company'].isnull().sum())
# Out:
# 0

# %%
data['Location'].fillna(data['Location'].mode()[0], inplace=True)
print(data['Location'])
# Out:
# 0                                         Yerevan, Armenia
# 1        IREX Armenia Main Office; Yerevan, Armenia \r\...
# 2                                         Yerevan, Armenia
# 3                                      Manila, Philippines
# 4                                         Yerevan, Armenia
#                                ...
# 18995                                     Yerevan, Armenia
# 18996                                     Yerevan, Armenia
# 18997                                     Yerevan, Armenia
# 18998                                     Yerevan, Armenia
# 18999                                     Yerevan, Armenia
# Name: Location, Length: 14918, dtype: object

# %%
print(data['Location'].isnull().sum())
# Out:
# 0

# %%
data['Duration'].fillna(data['Duration'].mode()[0], inplace=True)
print(data['Duration'])
# Out:
# 0                                             Long term
# 1                                              3 months
# 2                 Renewable annual contract\r\nPOSITION
# 3                                             Long term
# 4                                             Long term
#                               ...
# 18995    Long-term with a probation period of 3 months.
# 18996                                         Long-term
# 18997    Long-term with a probation period of 3 months.
# 18998    Long-term with a probation period of 3 months.
# 18999                                         Long-term
# Name: Duration, Length: 14918, dtype: object

# %%
print(data['Duration'].isnull().sum())
# Out:
# 0

# %%
data['OpeningDate'].fillna(data['OpeningDate'].mode()[0], inplace=True)
print(data['OpeningDate'])
# Out:
# 0       2012-08-20
# 1       2012-08-20
# 2       2012-08-20
# 3       2012-08-20
# 4       2012-08-20
#            ...
# 18995   2015-12-25
# 18996   2015-12-29
# 18997   2015-12-30
# 18998   2015-12-30
# 18999   2015-12-30
# Name: OpeningDate, Length: 14918, dtype: datetime64[ns]

# %%
print(data['OpeningDate'].isnull().sum())
# Out:
# 0

# %%
data.fillna({'Deadline':'Unknown'},inplace=True)

# %%
print(data.isnull().sum())
# Out:
# jobpost           0
# date              0
# Title             0
# Company           0
# Term              0
# Eligibility       0
# Audience          0
# StartDate         0
# Duration          0
# Location          0
# JobDescription    0
# JobRequirment     0
# RequiredQual      0
# Salary            0
# ApplicationP      0
# OpeningDate       0
# Deadline          0
# AboutC            0
# Year              0
# Month             0
# IT                0
# dtype: int64

# %%
data.columns
# Out:
# Index(['jobpost', 'date', 'Title', 'Company', 'Term', 'Eligibility',
#        'Audience', 'StartDate', 'Duration', 'Location', 'JobDescription',
#        'JobRequirment', 'RequiredQual', 'Salary', 'ApplicationP',
#        'OpeningDate', 'Deadline', 'AboutC', 'Year', 'Month', 'IT'],
#       dtype='object')

# %%
print(data['ApplicationP'].isnull().sum())
# Out:
# 0

# %%
print(data['ApplicationP'])
# Out:
# 0        To apply for this position, please submit a\r\...
# 1        Please submit a cover letter and resume to:\r\...
# 2        Please send resume or CV toursula.kazarian@......
# 3        Please send cover letter and resume to Amy\r\n...
# 4        Successful candidates should submit\r\n- CV; \...
#                                ...
# 18995    Interested candidates are asked to submit the\...
# 18996    To apply for this position, please send your\r...
# 18997    All interested candidates are kindly requested...
# 18998    All interested candidates are kindly requested...
# 18999    Interested candidates can send their CVs to:\r...
# Name: ApplicationP, Length: 14918, dtype: object

# %%
print(data.isnull().sum())
# Out:
# jobpost           0
# date              0
# Title             0
# Company           0
# Term              0
# Eligibility       0
# Audience          0
# StartDate         0
# Duration          0
# Location          0
# JobDescription    0
# JobRequirment     0
# RequiredQual      0
# Salary            0
# ApplicationP      0
# OpeningDate       0
# Deadline          0
# AboutC            0
# Year              0
# Month             0
# IT                0
# dtype: int64

# %%
data
# Out:
#                                                  jobpost          date  \
# 0      AMERIA Investment Consulting Company JOB TITLE...   Jan 5, 2004
# 1      International Research & Exchanges Board (IREX...   Jan 7, 2004
# 2      Caucasus Environmental NGO Network (CENN) JOB ...   Jan 7, 2004
# 3      Manoff Group JOB TITLE:  BCC Specialist POSITI...   Jan 7, 2004
# 4      Yerevan Brandy Company JOB TITLE:  Software De...  Jan 10, 2004
# ...                                                  ...           ...
# 18995  "Transport PIU" State Institution of the RA Mi...  Dec 24, 2015
# 18996  Technolinguistics NGO   TITLE:  Senior Creativ...  Dec 28, 2015
# 18997  "Coca-Cola Hellenic Bottling Company Armenia" ...  Dec 30, 2015
# 18998  "Coca-Cola Hellenic Bottling Company Armenia" ...  Dec 30, 2015
# 18999  San Lazzaro   LLC   TITLE:  Head of Online Sal...  Dec 30, 2015
#
#                                                    Title  \
# ...
